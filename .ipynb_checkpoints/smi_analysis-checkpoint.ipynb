# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from scipy.stats import probplot, yeojohnson

# %% [markdown]
# ## Load SMI data

# %% [markdown]
# Data source: https://data.snb.ch/de/topics/finma/cube/capchstocki?fromDate=2020-01-01&toDate=2024-12-22

# %%
raw = pd.read_csv("data/snb-data-pivoted-all-20241121_0900.csv", parse_dates=["Date"], index_col="Date")

# %%
raw.index = raw.index.to_period('D')

# %% [markdown]
# ## Clean & normalize data

# %%
index_clean = raw["Gesamtindex"].dropna()
index_daily = index_clean.div(index_clean.iloc[0]).mul(100)

# %%
index_daily.plot(grid=True, title="Normalized Swiss Market Index (SMI)")
plt.show()

# %%
fig, axs = plt.subplots(3,2, figsize=(8,6))
for i, period in enumerate([1, 30, 90, 182, 365]):
    print(f"Period = {period} days")
    index = index_daily.rolling(period).mean().dropna()

    # Check stationarity
    adf = adfuller(index.pct_change().dropna())
    print(f"Statistic: {adf[0]}")
    print(f"p-value: {adf[1]}")

    # Compute percentage change
    pch = index.pct_change().dropna()

    # Compute outlier fraction
    q25 = pch.quantile(0.25)
    q75 = pch.quantile(0.75)
    outl_mask = (pch<1.5*q25) | (pch>1.5*q75)
    print(f"Fraction of outliers: {100*np.round(sum(outl_mask)/len(outl_mask),4)}%")
    print()
    
    # Check Gaussianity
    probplot(pch, plot=axs[i//2,i%2])
    axs[i//2,i%2].set_title(f"Rolling window = {period} days") 
    axs[i//2,i%2].grid(True)
axs[2,1].axis("off")
plt.tight_layout()
plt.show()
# Out:
# Period = 1 days
# Statistic: -41.3922662476634
# p-value: 0.0
# Fraction of outliers: 33.08%
#
# Period = 30 days
# Statistic: -10.398647352608572
# p-value: 1.9352686839205596e-18
# Fraction of outliers: 32.98%
#
# Period = 90 days
# Statistic: -7.453458527569476
# p-value: 5.5915216852274975e-11
# Fraction of outliers: 31.069999999999997%
#
# Period = 182 days
# Statistic: -4.920003625661405
# p-value: 3.187890036330605e-05
# Fraction of outliers: 33.82%
#
# Period = 365 days
# Statistic: -3.316342704429534
# p-value: 0.014163573627586551
# Fraction of outliers: 33.18%

# %%
index_semiy = index_daily.rolling(182).mean().dropna()
pch_semiy = index_semiy.pct_change().dropna()

# %% [markdown]
# ## Make time series stationary for further analysis

# %% [markdown]
# We find, that the percentage changes of the normalized SMI time series is stationary.

# %%
stat_ts = pch_semiy.dropna()

# %%
stat_ts.info()
# Out:
# <class 'pandas.core.series.Series'>
# PeriodIndex: 8851 entries, 1989-09-22 to 2024-11-15
# Freq: D
# Series name: Gesamtindex
# Non-Null Count  Dtype
# --------------  -----
# 8851 non-null   float64
# dtypes: float64(1)
# memory usage: 138.3 KB

# %%
ser, lmda = yeojohnson(stat_ts)#.apply(lambda x: np.log(x+0.002)).diff(365).diff(365).dropna()

# %%
ser_trf=pd.Series(ser, index=stat_ts.index)
ser_trf
# Out:
# Date
# 1989-09-22    0.001442
# 1989-09-25    0.001446
# 1989-09-26    0.001307
# 1989-09-27    0.001196
# 1989-09-28    0.001216
#                 ...
# 2024-11-11    0.000337
# 2024-11-12    0.000264
# 2024-11-13    0.000212
# 2024-11-14    0.000271
# 2024-11-15    0.000208
# Freq: D, Length: 8851, dtype: float64

# %%
fig, ax = plt.subplots()
stat_ts.plot(title="Percentage change of SMI", c="b", ax=ax)
ser_trf.plot(grid=True, ax=ax, ls=":", c="orange")
ax.axhline(y=ser.mean(), c="b", ls="-", lw=2)
ax.axhline(y=ser_trf.mean(), c="orange", ls="--", lw=2)
plt.show()

# %%
fig, axs = plt.subplots(2,1, sharex=True, figsize=(10,4),gridspec_kw={'height_ratios':[1,3]})
ax = axs[0]
df = pd.concat([stat_ts, ser_trf], axis=1)
df.rename(columns={"Gesamtindex": "original", 0: "yeo-johnson trafo"}, inplace=True)
df.plot(kind="box", vert=False, ax=ax, grid=True)
ax = axs[1]
stat_ts.plot(kind="hist", bins=50, grid=True, facecolor="blue", ax=ax, alpha=0.5, label="original")
ser_trf.plot(kind="hist", bins=50, grid=True, facecolor="orange", ax=ax, alpha=0.5, label="yeo-johnson trafo")
ax.legend(loc="best")
plt.show()

# %% [markdown]
# The visualization above shows that the original and the Yeo-Johnson transformed data exhibit very similar characteristics: both have quite heavy tails and are strictly speaking bi-modal. Therefore, we concluse that the Yeo-Johnson transformation does not transform the original data into a normal distribution enough to be satisfactory. As a result, we shall continue with the original, untransformed data.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,4))
ax = axs[0]
plot_acf(stat_ts.dropna(), lags=[1]+[10*i for i in range(1,55)], zero=False, ax=ax)
ax.set_ylim([-0.3, 1.1])
ax.grid(True)

ax = axs[1]
plot_pacf(stat_ts.dropna(), lags=[1]+[10*i for i in range(1,55)]+[183, 365, 547], zero=False, ax=ax)
ax.set_ylim([-0.1, 1.1])
ax.grid(True)
plt.show()

# %% [markdown]
# From the above (partial) autocorrelation plots we can deduce the following two insights:
#
# 1) The time series in stats_ts closely resembles an AR(1) model
# 2) There is still some periodicity in the data which we'll need to eliminate

# %% [markdown]
# ## Find best ARIMA model

# %%
meas = {"p": [], "d": [], "q": [], "AIC": [], "BIC": []}

for p in range(3):
    for d in range(3):
        for q in range(3):
            print(p,d,q)
            meas["p"].append(p)
            meas["d"].append(d)
            meas["q"].append(q)
            model = ARIMA(stat_ts, order=(p,d,q))

            try:
                res=model.fit()
                meas["AIC"].append(res.aic)
                meas["BIC"].append(res.bic)
            except:
                meas["AIC"].append(None)
                meas["BIC"].append(None)
                continue
# Out:
# 0 0 0
# 0 0 1
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# 0 0 2
# 0 1 0
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 0 1 1
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 0 1 2
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 0 2 0
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 0 2 1
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 0 2 2
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 0 0
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 0 1
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 0 2
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 1 0
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 1 1
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 1 2
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 2 0
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 2 1
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 1 2 2
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 2 0 0
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 2 0 1
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 2 0 2
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 2 1 0
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 2 1 1
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 2 1 2
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 2 2 0
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 2 2 1
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# 2 2 2
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
meas_df = pd.DataFrame.from_dict(meas)

# %%
meas_df[meas_df["AIC"]==meas_df["AIC"].min()]
# Out:
#     p  d  q            AIC            BIC
# 11  1  0  2 -142359.018455 -142323.577026

# %%
meas_df[meas_df["BIC"]==meas_df["BIC"].min()]
# Out:
#     p  d  q            AIC            BIC
# 10  1  0  1 -142352.382711 -142324.029568

# %%
model1 = ARIMA(stat_ts, order=(1,0,1))
res1 = model1.fit()
res1.plot_diagnostics()
plt.show()
# Out:
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model2 = ARIMA(stat_ts, order=(1,0,2))
res2 = model2.fit()
res2.plot_diagnostics()
plt.show()
# Out:
# /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
meas = {"p": [], "d": [], "q": [], "AIC": [], "BIC": []}

for p in range(5):
    for d in range(1,3):
        for q in range(5):
            print(p,d,q)
            meas["p"].append(p)
            meas["d"].append(d)
            meas["q"].append(q)
            model = ARIMA(stat_ts, order=(p,d,q))

            try:
                res=model.fit()
                meas["AIC"].append(res.aic)
                meas["BIC"].append(res.bic)
            except:
                meas["AIC"].append(None)
                meas["BIC"].append(None)
                continue

# %%
meas_df = pd.DataFrame.from_dict(meas)

# %%
meas_df[meas_df["BIC"]==meas_df["BIC"].min()]

# %%
model1 = ARIMA(stat_ts, order=(0,1,2))
res1 = model1.fit()
res1.plot_diagnostics()
plt.show()

# %%
model2 = ARIMA(stat_ts, order=(3,1,4))
res2 = model2.fit()
res2.plot_diagnostics()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp_results = seasonal_decompose(stat_ts.to_frame())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 decomp_results = seasonal_decompose(stat_ts.to_frame())
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/tsa/seasonal.py:167, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     165         period = pfreq
#     166     else:
# --> 167         raise ValueError(
#     168             "You must specify a period or x must be a pandas object with "
#     169             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     170         )
#     171 if x.shape[0] < 2 * pfreq:
#     172     raise ValueError(
#     173         f"x must have 2 complete cycles requires {2 * pfreq} "
#     174         f"observations. x only has {x.shape[0]} observation(s)"
#     175     )
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None

# %%
decomp_results.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/matplotlib/axis.py:1813, in Axis.convert_units(self, x)
#    1812 try:
# -> 1813     ret = self.converter.convert(x, self.units, self)
#    1814 except Exception as e:
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/pandas/plotting/_matplotlib/converter.py:237, in PeriodConverter.convert(values, units, axis)
#     236 else:
# --> 237     values = PeriodConverter._convert_1d(values, units, axis)
#     238 return values
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/pandas/plotting/_matplotlib/converter.py:243, in PeriodConverter._convert_1d(values, units, axis)
#     242 if not hasattr(axis, "freq"):
# --> 243     raise TypeError("Axis must have `freq` set to convert to Periods")
#     244 valid_types = (str, datetime, Period, pydt.date, pydt.time, np.datetime64)
#
# TypeError: Axis must have `freq` set to convert to Periods
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 decomp_results.plot()
#       2 plt.show()
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/statsmodels/tsa/seasonal.py:349, in DecomposeResult.plot(self, observed, seasonal, trend, resid, weights)
#     347 for i, (ax, (series, def_name)) in enumerate(zip(axs, series)):
#     348     if def_name != "residual":
# --> 349         ax.plot(series)
#     350     else:
#     351         ax.plot(series, marker="o", linestyle="none")
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/matplotlib/axes/_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/matplotlib/axes/_base.py:481, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     478     x, y = index_of(xy[-1])
#     480 if axes.xaxis is not None:
# --> 481     axes.xaxis.update_units(x)
#     482 if axes.yaxis is not None:
#     483     axes.yaxis.update_units(y)
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/matplotlib/axis.py:1761, in Axis.update_units(self, data)
#    1758     self.set_units(default)
#    1760 elif neednew:
# -> 1761     self._update_axisinfo()
#    1762 self.stale = True
#    1763 return True
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/matplotlib/axis.py:1797, in Axis._update_axisinfo(self)
#    1794     self.set_label_text(info.label)
#    1795     self.isDefault_label = True
# -> 1797 self.set_default_intervals()
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/matplotlib/axis.py:2555, in XAxis.set_default_intervals(self)
#    2553         info = self.converter.axisinfo(self.units, self)
#    2554         if info.default_limits is not None:
# -> 2555             xmin, xmax = self.convert_units(info.default_limits)
#    2556             self.axes.viewLim.intervalx = xmin, xmax
#    2557 self.stale = True
#
# File /usr/local/Caskroom/miniconda/base/envs/timeseries/lib/python3.12/site-packages/matplotlib/axis.py:1815, in Axis.convert_units(self, x)
#    1813     ret = self.converter.convert(x, self.units, self)
#    1814 except Exception as e:
# -> 1815     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1816                                  f'units: {x!r}') from e
#    1817 return ret
#
# ConversionError: Failed to convert value(s) to axis units: (datetime.date(1970, 1, 1), datetime.date(1970, 1, 2))

# %%
# Out:
#             Gesamtindex
# Date
# 1989-09-22     0.001267
# 1989-09-25     0.001270
# 1989-09-26     0.001162
# 1989-09-27     0.001073
# 1989-09-28     0.001089
# ...                 ...
# 2024-11-11     0.000327
# 2024-11-12     0.000257
# 2024-11-13     0.000207
# 2024-11-14     0.000264
# 2024-11-15     0.000204
#
# [8851 rows x 1 columns]
